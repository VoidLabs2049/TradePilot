# %%
  import duckdb

  daily = duckdb.sql("""
      SELECT *
      FROM read_parquet(
          'data/lakehouse/normalized/'
          'market.futures_contract_daily/*/*/*.parquet'
      )
      WHERE contract_code = 'M2609.DCE'
        AND trade_date BETWEEN DATE '2026-04-01' AND DATE '2026-04-15'
      ORDER BY trade_date
  """).df()

# %%
  import duckdb

  daily = duckdb.sql("""
      SELECT *
      FROM read_parquet(
          'data/lakehouse/normalized/'
          'market.futures_contract_daily/*/*/*.parquet'
      )
      WHERE contract_code = 'M2609.DCE'
        AND trade_date BETWEEN DATE '2026-04-01' AND DATE '2026-04-15'
      ORDER BY trade_date
  """).df()

  daily

# %%
  mapping = duckdb.sql("""
      SELECT *
      FROM read_parquet(
          'data/lakehouse/normalized/'
          'market.futures_mapping/*/*/*.parquet'
      )
      WHERE root_code = 'M.DCE'
        AND trade_date BETWEEN DATE '2026-04-01' AND DATE '2026-04-15'
      ORDER BY trade_date
  """).df()

  mapping
